# %%
from notebook_utils import export_image_to_video_conversions, make_movie_from_runs
from IPython.display import Video

# %%
final_video_path = make_movie_from_foreach_run(
    run_id = "586",
    save_folder="final_render",
    final_video_path="latest_images_test.mp4"
)
# Out:
# ['final_render/586/4f73094/video.mp4']
# 1
# Moviepy - Building video latest_images_test.mp4.
# Moviepy - Writing video latest_images_test.mp4
# Moviepy - Done !
# Moviepy - video ready latest_images_test.mp4

# %%
Video(final_video_path, embed=True)
# Out:
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>
